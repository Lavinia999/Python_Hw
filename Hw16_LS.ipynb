# %%
#16Homework

# %%
import requests
CLIENT_ID='1962371e94834594a28eb7e643a4e16f'
CLIENT_SECRET='0079dbe9a0e542d6a03f64256e35bba8'
AUTH_URL='https://accounts.spotify.com/api/token'
auth_response=requests.post(AUTH_URL,{
    'grant_type':'client_credentials',
    'client_id':CLIENT_ID,
    'client_secret':CLIENT_SECRET,
})
auth_response
# Out:
# <Response [200]>

# %%
auth_response_data=auth_response.json()
acces_token=auth_response_data['access_token']
acces_token
# Out:
# 'BQAs57muvQgm_yU6Duwozj5amtQGStar-P_QXBgvxBjmH_zYRzIqPv-Ppo4rIGngU1AlVD_2zh1XM896ncI'

# %%
header={
    'Authorization':'Bearer {}'.format(acces_token)
}
BASE_URL = 'https://api.spotify.com/v1/'
track_id = '6y0igZArWVi6Iz0rj35c1Y'
r=requests.get(BASE_URL+'audio-features/' + track_id,headers=header)
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# {'danceability': 0.54,
#  'energy': 0.59,
#  'key': 0,
#  'loudness': -4.359,
#  'mode': 1,
#  'speechiness': 0.0528,
#  'acousticness': 0.446,
#  'instrumentalness': 0,
#  'liveness': 0.14,
#  'valence': 0.267,
#  'tempo': 119.878,
#  'type': 'audio_features',
#  'id': '6y0igZArWVi6Iz0rj35c1Y',
#  'uri': 'spotify:track:6y0igZArWVi6Iz0rj35c1Y',
#  'track_href': 'https://api.spotify.com/v1/tracks/6y0igZArWVi6Iz0rj35c1Y',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6y0igZArWVi6Iz0rj35c1Y',
#  'duration_ms': 234910,
#  'time_signature': 4}

# %%
artist_id = '7x3f7c0fBanNlQwpx1255g'

# %%
r=requests.get(BASE_URL+'artists/'+artist_id+'/albums',headers=header)
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
#   'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/50fMOTyyX2sSw8dNM2Kzfz'},
# ...

# %%
data=r.json()['items']

# %%
data
# Out:
# 5196834fd783cbe51ed0cd048a',
#     'width': 64}],
#   'name': 'Gin Tonic',
#   'release_date': '1980',
#   'release_date_precision': 'year',
#   'total_tracks': 11,
#   'type': 'album',
#   'uri': 'spotify:album:3pqgcjkKztyJL55yMmPnBk'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7x3f7c0fBanNlQwpx1255g'},
#     'href': 'https://api.spotify.com/v1/artists/7x3f7c0fBanNlQwpx1255g',
#     'id': '7x3f7c0fBanNlQwpx1255g',
#     'name': 'Françoise Hardy',
#     'type': 'artist',
#     'uri': 'spotify:artist:7x3f7c0fBanNlQwpx1255g'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
# ...

# %%
len(data)
# Out:
# 20

# %%
track_num=0
for album in data:
    track_num += album['total_tracks']
track_num
# Out:
# 300

# %%
album_ids=[album['id'] for album in data]
album_ids
# Out:
# ['2CVM9sssRF0aepooXNeeLt',
#  '0F42Y0ITVGDNNRksPwgQiR',
#  '4J2xIndlY24MV9dFGttDDV',
#  '6ReVoS6aGTfNChW0MLqPNa',
#  '7092Q6T4ZdcQIOVjRejfbZ',
#  '3WYGpGCzFPEzqcZ77FJSWQ',
#  '2eKKxmSQWy1r1xEGeJSLmX',
#  '6avwv7EX09YlpCtf2scZUX',
#  '0ccMLn7DlKbdGZWY6ItEmK',
#  '0qcFJLi0PG2p4iiNwwAs81',
#  '7AQwnHikEkznSynvb0HnO0',
#  '3pqgcjkKztyJL55yMmPnBk',
#  '50fMOTyyX2sSw8dNM2Kzfz',
#  '6QDsTPYx2cMiPT5jME2yzc',
#  '3zK7ENr1tBSRjRpe7HIVl2',
#  '5ZwlOcxszBn5GACtzs6sE6',
#  '2tNwTEAUVbCpSf9JtJkOBb',
#  '3HbycLyvAKAl5ThVNFM91H',
#  '2VlEF6dWZ9iwpo8B12vCEA',
#  '42FkWEwDRihRWbsOdZmLSn']

# %%
r = requests.get(BASE_URL + 'albums/' + '2CVM9sssRF0aepooXNeeLt' + '/tracks', 
                headers=header)
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
#    'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
# ...

# %%
#Names of tracks
tracks = []
for album_id in album_ids:
    r = requests.get(BASE_URL + 'albums/' + album_id + '/tracks', 
                headers=header)
    data = r.json()['items']
    for track in data:
        tracks.append(track['name'])
tracks
# Out:
# ['Tous les garçons et les filles',
#  'Ça raté',
#  'La fille avec toi',
#  'Oh oh chéri (Uh oh)',
#  "Le temps de l'amour",
#  'Il est tout pour moi',
#  'On se plaît',
#  'Ton meilleur ami',
#  "J'ai jeté mon cœur",
#  'Il est parti un jour',
#  "J'suis d'accord",
#  "C'est à l'amour auquel je pense",
#  'À cache-cache',
#  'Dors mon ange',
#  "Personne d'autre",
#  'Un seul geste',
#  "You're My Home",
#  'Seras-tu là ?',
#  'Quel dommage',
#  'Train spécial',
#  'Brumes',
#  'Trois petits tours',
#  'Le large',
#  'Un mal qui fait du bien',
#  'Tous les garçons et les filles - Slow',
#  'Oh oh chéri',
#  "Je suis d'accord - Twist",
#  "Le temps de l'amour - Fox Medium",
#  'Le premier bonheur du jour',
#  "J'aurais voulu",
#  'Et même... - Première version',
#  "Je veux qu'il revienne",
#  'Mon amie la rose',
#  'Pars',
#  "Tu n'as qu'un mot à dire",
#  "Pourtant tu m'aimes",
#  "L'amitié",
#  "Je changerais d'avis - Se Telefonando",
#  'Il est des choses',
#  'Comme',
# ...

# %%
len(tracks)
# Out:
# 267

# %%
#Time of getting the names of tracks
import timeit
# %%timeit
tracks=[]
for album_id in album_ids:
    r=requests.get(BASE_URL+'albums/'+album_id+'/tracks',headres=header)
    data=r.json()['items']
    for track in data:
        tracks.append(track['name'])
# Out:
# UsageError: Line magic function `%%timeit` not found.

# %%
#save the list of tracks
import json
json.dump(album_ids, open('albums_ids.json', 'w'))
